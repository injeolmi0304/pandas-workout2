# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# Load the CSV file with results from the Python survey into a data frame.
py_filename = '../data/2020_sharing_data_outside.csv'

py_df = pd.read_csv(py_filename, low_memory=False)

# %%
py_df.head()
# Out:
#   is.python.main  other.lang.None other.lang.Java other.lang.JavaScript  \
# 0            Yes              NaN             NaN                   NaN
# 1            Yes              NaN            Java            JavaScript
# 2            Yes              NaN             NaN                   NaN
# 3            Yes              NaN             NaN            JavaScript
# 4            Yes              NaN            Java            JavaScript
#
#   other.lang.C/C++ other.lang.PHP other.lang.C# other.lang.Ruby  \
# 0              NaN            NaN           NaN             NaN
# 1              NaN            NaN            C#             NaN
# 2            C/C++            NaN           NaN             NaN
# 3              NaN            NaN           NaN             NaN
# 4            C/C++            NaN           NaN             NaN
#
#   other.lang.Bash / Shell other.lang.Objective-C  ...  \
# 0            Bash / Shell                    NaN  ...
# 1                     NaN                    NaN  ...
# 2            Bash / Shell                    NaN  ...
# 3            Bash / Shell                    NaN  ...
# 4            Bash / Shell                    NaN  ...
#
#   job.role.Technical support job.role.Data analyst job.role.Business analyst  \
# 0                        NaN                   NaN          Business analyst
# 1                        NaN                   NaN                       NaN
# 2          Technical support          Data analyst                       NaN
# 3                        NaN                   NaN                       NaN
# 4                        NaN                   NaN                       NaN
#
#   job.role.Team lead job.role.Product manager job.role.CIO / CEO / CTO  \
# 0                NaN                      NaN                      NaN
# 1                NaN                      NaN                      NaN
# 2          Team lead                      NaN                      NaN
# 3                NaN                      NaN                      NaN
# 4                NaN                      NaN                      NaN
#
#   job.role.Systems analyst job.role.Other    age   country.live
# 0                      NaN            NaN  30–39            NaN
# 1                      NaN            NaN  21–29          India
# 2                      NaN            NaN  30–39  United States
# 3                      NaN            NaN    NaN            NaN
# 4                      NaN            NaN  21–29          Italy
#
# [5 rows x 264 columns]

# %%
# Rename some columns

general_columns = ['age',
                   'are.you.datascientist',
                   'company.size',
                   'country.live',
                   'employment.status',
                   'first.learn.about.main.ide',
                   'how.often.use.main.ide',
                   'is.python.main',
                   'main.purposes',
                   'missing.features.main.ide',
                   'nps.main.ide',
                   'python.version.most',
                   'python.years',
                   'python2.version.most',
                   'python3.version.most',
                   'several.projects',
                   'team.size',
                   'use.python.most',
                   'years.of.coding'
                  ]

# Use the function `pd.MultiIndex.from_tuples` to create the multi-index, 
# and then reassign it back to `df.columns`. 

def column_multi_name(column_name):
    if column_name in general_columns:
        return ('general', column_name)
    else:
        first, rest = column_name.rsplit('.', 1)
        return (first, rest)
    
py_df.columns = pd.MultiIndex.from_tuples([column_multi_name(one_column_name)
                  for one_column_name in py_df.columns    ])

# %%
py_df.head()
# Out:
#          general other.lang                                          \
#   is.python.main       None  Java  JavaScript  C/C++  PHP   C# Ruby
# 0            Yes        NaN   NaN         NaN    NaN  NaN  NaN  NaN
# 1            Yes        NaN  Java  JavaScript    NaN  NaN   C#  NaN
# 2            Yes        NaN   NaN         NaN  C/C++  NaN  NaN  NaN
# 3            Yes        NaN   NaN  JavaScript    NaN  NaN  NaN  NaN
# 4            Yes        NaN  Java  JavaScript  C/C++  NaN  NaN  NaN
#
#                              ...           job.role                \
#    Bash / Shell Objective-C  ...  Technical support  Data analyst
# 0  Bash / Shell         NaN  ...                NaN           NaN
# 1           NaN         NaN  ...                NaN           NaN
# 2  Bash / Shell         NaN  ...  Technical support  Data analyst
# 3  Bash / Shell         NaN  ...                NaN           NaN
# 4  Bash / Shell         NaN  ...                NaN           NaN
#
#                                                                 \
#    Business analyst  Team lead Product manager CIO / CEO / CTO
# 0  Business analyst        NaN             NaN             NaN
# 1               NaN        NaN             NaN             NaN
# 2               NaN  Team lead             NaN             NaN
# 3               NaN        NaN             NaN             NaN
# 4               NaN        NaN             NaN             NaN
#
#                         general
#   Systems analyst Other     age   country.live
# 0             NaN   NaN   30–39            NaN
# 1             NaN   NaN   21–29          India
# 2             NaN   NaN   30–39  United States
# 3             NaN   NaN     NaN            NaN
# 4             NaN   NaN   21–29          Italy
#
# [5 rows x 264 columns]

# %%
# Sort the columns, such that they're in alphabetical order. 
py_df = py_df[sorted(py_df.columns)]

# %%
py_df.head()
# Out:
#        bigdata                                                                \
#    Apache Beam Apache Flink Apache Hadoop/MapReduce Apache Hive Apache Kafka
# 0  Apache Beam          NaN                     NaN         NaN          NaN
# 1          NaN          NaN                     NaN         NaN          NaN
# 2          NaN          NaN                     NaN         NaN          NaN
# 3          NaN          NaN                     NaN         NaN          NaN
# 4          NaN          NaN                     NaN         NaN          NaN
#
#                                                         ... web.frameworks  \
#   Apache Samza Apache Spark Apache Tez ClickHouse Dask  ...         Django
# 0          NaN          NaN        NaN        NaN  NaN  ...            NaN
# 1          NaN          NaN        NaN        NaN  NaN  ...            NaN
# 2          NaN          NaN        NaN        NaN  NaN  ...            NaN
# 3          NaN          NaN        NaN        NaN  NaN  ...         Django
# 4          NaN          NaN        NaN        NaN  NaN  ...            NaN
#
#
#   Falcon FastAPI  Flask   Hug None Other Pyramid   Tornado web2py
# 0    NaN     NaN     NaN  NaN  NaN   NaN      NaN      NaN    NaN
# 1    NaN     NaN     NaN  NaN  NaN   NaN      NaN  Tornado    NaN
# 2    NaN     NaN  Flask   NaN  NaN   NaN      NaN      NaN    NaN
# 3    NaN     NaN     NaN  NaN  NaN   NaN      NaN      NaN    NaN
# 4    NaN     NaN  Flask   NaN  NaN   NaN      NaN      NaN    NaN
#
# [5 rows x 264 columns]

# %%
# What are the 10 most popular IDEs used for editing Python?
# Python을 사용하는 응답자만 필터링
mask = (py_df.loc[:, ('general', 'is.python.main')] == 'Yes') | \
       (py_df.loc[:, ('general', 'is.python.main')] == 'No, I use Python as a secondary language')

py_df.loc[mask, ('ide', 'main')].value_counts().head(10)
# Out:
# (ide, main)
# VS Code                         8010
# PyCharm Professional Edition    5144
# PyCharm Community Edition       3815
# Vim                             2176
# Sublime Text                    1201
# Jupyter Notebook                1167
# Atom                             784
# Other                            711
# Emacs                            635
# Spyder                           580
# Name: count, dtype: int64

# %%
# Python을 주요 언어로 사용하는 응답자만 필터링할 경우
mask = py_df.loc[:, ('general', 'is.python.main')] == 'Yes'

py_df.loc[mask, ('ide', 'main')].value_counts().head(10)
# Out:
# (ide, main)
# VS Code                         6770
# PyCharm Professional Edition    4633
# PyCharm Community Edition       3282
# Vim                             1834
# Sublime Text                    1065
# Jupyter Notebook                1038
# Atom                             668
# Other                            594
# Emacs                            525
# Spyder                           501
# Name: count, dtype: int64

# %%
# Which 10 other programming languages are most commonly used by Python developers?
(
    py_df['other.lang']
    .count()
    .sort_values(ascending=False)
    .head(10)
)
# Out:
# JavaScript      16662
# HTML/CSS        15469
# Bash / Shell    13793
# SQL             13391
# C/C++           11623
# Java             8109
# C#               4460
# PHP              4060
# TypeScript       3717
# Other            3592
# dtype: int64

# %% [markdown]
# 파이썬을 주요 또는 보조 언어로 사용하는 개발자들이 가장 많이 사용하는 다른 프로그래밍 언어 10가지는 다음과 같다.

# %%
# Which 10 other programming languages are most commonly used by Python developers?
mask = (py_df[('general','is.python.main')] == 'Yes') | \
       (py_df[('general','is.python.main')] == 'No, I use Python as a secondary language')

(
    py_df.loc[mask, 'other.lang']
    .count()
    .sort_values(ascending=False)
    .head(10)
)
# Out:
# JavaScript      16139
# HTML/CSS        14954
# Bash / Shell    13582
# SQL             12994
# C/C++           11192
# Java             7709
# C#               4225
# PHP              3816
# TypeScript       3575
# Other            3364
# dtype: int64

# %%
# What were the 10 most common countries from which survey participants came?
(
    py_df[('general', 'country.live')]
    .value_counts()
    .head(10)
)
# Out:
# (general, country.live)
# United States         3975
# India                 2800
# Germany               1807
# China                 1155
# United Kingdom        1110
# France                1078
# Russian Federation     935
# Other country          880
# Brazil                 812
# Canada                 644
# Name: count, dtype: int64

# %%
# According to the Python survey, what proportion of Python developers have each level of experience?

(
    py_df[('general', 'python.years')]
    .value_counts(normalize=True)
)
# Out:
# (general, python.years)
# 3–5 years           0.284272
# Less than 1 year    0.239542
# 1–2 years           0.224834
# 6–10 years          0.154939
# 11+ years           0.096413
# Name: proportion, dtype: float64

# %%
# Which country has the greatest number of Python developers with 11+ years of experience?
(
    py_df['general']
    [py_df[('general','python.years')] == '11+ years']
    .groupby('country.live')['python.years']
    .count()
    .sort_values(ascending=False)
    .head(1)
)
# Out:
# country.live
# United States    691
# Name: python.years, dtype: int64

# %%
# Proportion of Python devs per country with 11+years experience
country_experience = py_df['general'][['country.live', 'python.years']]
all_per_country = country_experience['country.live'].value_counts()

# %%
all_per_country
# Out:
# country.live
# United States         3975
# India                 2800
# Germany               1807
# China                 1155
# United Kingdom        1110
#                       ...
# Kazakhstan              36
# Dominican Republic      34
# Uruguay                 33
# Armenia                 31
# Uzbekistan              31
# Name: count, Length: 76, dtype: int64

# %%
expert_per_country = (country_experience
                      .loc[
                          country_experience['python.years'] == '11+ years', 
                          'country.live']
                      .value_counts()
                     )

# %%
expert_per_country
# Out:
# country.live
# United States     691
# Germany           308
# United Kingdom    207
# France            166
# Canada             94
#                  ...
# Pakistan            1
# Tunisia             1
# Nigeria             1
# Ghana               1
# Egypt               1
# Name: count, Length: 70, dtype: int64

# %%
(expert_per_country / all_per_country).sort_values(ascending=False).dropna().head(10)
# Out:
# country.live
# Norway            0.265432
# Ireland           0.225490
# Australia         0.225420
# Belgium           0.225108
# Slovenia          0.224490
# New Zealand       0.197917
# Sweden            0.194030
# Finland           0.190141
# United Kingdom    0.186486
# Austria           0.186170
# Name: count, dtype: float64

# %%
# Load the CSV file with results from the Stack Overflow survey into a data frame.
so_filename = '../data/so_2021_survey_results.csv'

so_df = pd.read_csv(so_filename, low_memory=False)

# %%
so_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode  ...  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN  ...
# 1  Other online resources (ex: videos, blogs, etc...         7  ...
# 2  Other online resources (ex: videos, blogs, etc...       NaN  ...
# 3                                                NaN       NaN  ...
# 4                            Friend or family member        17  ...
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#   ConvertedCompYearly
# 0             62268.0
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# 한국, 영국, 미국의 이름을 이후에 불러오는 OECD 데이터에서 사용된 국가명과 통일시킨다.

# %%
to_replace_dict = {'South Korea' : 'Korea',
                   'Republic of Korea' : 'Korea',
                    'United States of America' : 'United States',
                    'United Kingdom of Great Britain and Northern Ireland' : 'United Kingdom'
                    }
so_df['Country'] = so_df['Country'].replace(to_replace=to_replace_dict)

# %%
# Show the average salary for different types of employment. 
# Contractors and freelancers like to say that they earn more than full-time employees. 
# What does the data here show us?

(
    so_df
    .groupby('Employment')['ConvertedCompYearly'].mean()
    .sort_values(ascending=False)
    .dropna()
    .apply(lambda n: f'{n:,.2f}')
)
# Out:
# Employment
# I prefer not to say                                     1,455,643.25
# Employed full-time                                        121,369.67
# Independent contractor, freelancer, or self-employed      107,433.97
# Retired                                                    69,533.25
# Employed part-time                                         41,136.12
# Name: ConvertedCompYearly, dtype: object

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
so_df[['Country', 'EdLevel', 'ConvertedCompYearly']]
# Out:
#                   Country                                            EdLevel  \
# 0                Slovakia  Secondary school (e.g. American high school, G...
# 1             Netherlands       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      Russian Federation       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 Austria    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4          United Kingdom    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                   ...                                                ...
# 83434       United States       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435               Benin       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436       United States  Secondary school (e.g. American high school, G...
# 83437              Canada       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438              Brazil                 Professional degree (JD, MD, etc.)
#
#        ConvertedCompYearly
# 0                62,268.00
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 83434           160,500.00
# 83435             3,960.00
# 83436            90,000.00
# 83437           816,816.00
# 83438            21,168.00
#
# [83439 rows x 3 columns]

# %%
# Create a pivot table in which the index contains countries, 
# the columns are education levels, 
# and the cells contain the average salary for each education level per country.

(
    so_df
    .pivot_table(index='Country', 
                 columns='EdLevel', 
                 values='ConvertedCompYearly')
)
# Out:
# EdLevel                               Associate degree (A.A., A.S., etc.)  \
# Country
# Afghanistan                                                           NaN
# Albania                                                               NaN
# Algeria                                                               NaN
# Andorra                                                               NaN
# Angola                                                                NaN
# ...                                                                   ...
# Venezuela, Bolivarian Republic of...                                  NaN
# Viet Nam                                                         7,827.00
# Yemen                                                                 NaN
# Zambia                                                                NaN
# Zimbabwe                                                        36,000.00
#
# EdLevel                               Bachelor’s degree (B.A., B.S., B.Eng., etc.)  \
# Country
# Afghanistan                                                              30,288.00
# Albania                                                                  19,152.86
# Algeria                                                                  21,770.67
# Andorra                                                                  94,045.50
# Angola                                                                   31,500.00
# ...                                                                            ...
# Venezuela, Bolivarian Republic of...                                     30,108.77
# Viet Nam                                                                 18,463.11
# Yemen                                                                     5,628.67
# Zambia                                                                   40,173.00
# Zimbabwe                                                                  8,399.27
#
# EdLevel                               Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  \
# Country
# Afghanistan                                                             10,176,704.00
# Albania                                                                     80,127.62
# Algeria                                                                     15,052.57
# Andorra                                                                     22,056.00
# Angola                                                                            NaN
# ...                                                                               ...
# Venezuela, Bolivarian Republic of...                                        28,680.00
# Viet Nam                                                                    50,599.80
# Yemen                                                                             NaN
# Zambia                                                                       4,908.00
# Zimbabwe                                                                          NaN
#
# EdLevel                               Other doctoral degree (Ph.D., Ed.D., etc.)  \
# Country
# Afghanistan                                                                  NaN
# Albania                                                                      NaN
# Algeria                                                                      NaN
# Andorra                                                               146,981.00
# Angola                                                                       NaN
# ...                                                                          ...
# Venezuela, Bolivarian Republic of...                                         NaN
# Viet Nam                                                                2,592.00
# Yemen                                                                        NaN
# Zambia                                                                       NaN
# Zimbabwe                                                                     NaN
#
# EdLevel                               Primary/elementary school  \
# Country
# Afghanistan                                                 NaN
# Albania                                                     NaN
# Algeria                                                     NaN
# Andorra                                                     NaN
# Angola                                                      NaN
# ...                                                         ...
# Venezuela, Bolivarian Republic of...                   7,200.00
# Viet Nam                                              10,479.00
# Yemen                                                       NaN
# Zambia                                                      NaN
# Zimbabwe                                                    NaN
#
# EdLevel                               Professional degree (JD, MD, etc.)  \
# Country
# Afghanistan                                                          NaN
# Albania                                                         5,298.00
# Algeria                                                        12,912.00
# Andorra                                                              NaN
# Angola                                                               NaN
# ...                                                                  ...
# Venezuela, Bolivarian Republic of...                           14,833.29
# Viet Nam                                                       30,000.00
# Yemen                                                                NaN
# Zambia                                                               NaN
# Zimbabwe                                                             NaN
#
# EdLevel                               Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)  \
# Country
# Afghanistan                                                                      100.00
# Albania                                                                       19,890.00
# Algeria                                                                             NaN
# Andorra                                                                             NaN
# Angola                                                                        18,678.00
# ...                                                                                 ...
# Venezuela, Bolivarian Republic of...                                          10,200.00
# Viet Nam                                                                            NaN
# Yemen                                                                               NaN
# Zambia                                                                         4,482.00
# Zimbabwe                                                                            NaN
#
# EdLevel                               Some college/university study without earning a degree  \
# Country
# Afghanistan                                                                         NaN
# Albania                                                                       22,884.00
# Algeria                                                                        6,288.00
# Andorra                                                                             NaN
# Angola                                                                         6,904.00
# ...                                                                                 ...
# Venezuela, Bolivarian Republic of...                                          17,720.57
# Viet Nam                                                                      18,866.19
# Yemen                                                                               NaN
# Zambia                                                                        12,105.33
# Zimbabwe                                                                      20,000.00
#
# EdLevel                               Something else
# Country
# Afghanistan                                      NaN
# Albania                                   128,522.00
# Algeria                                          NaN
# Andorra                                          NaN
# Angola                                           NaN
# ...                                              ...
# Venezuela, Bolivarian Republic of...             NaN
# Viet Nam                                         NaN
# Yemen                                            NaN
# Zambia                                      8,184.00
# Zimbabwe                                         NaN
#
# [170 rows x 9 columns]

# %%
# Load the CSV file with OECD data
oecd_filename = '../data/oecd_locations.csv'

oecd_df = pd.read_csv(oecd_filename, header=None, index_col=1, names=['abbrev', 'Country'])

# %%
oecd_df
# Out:
#                abbrev
# Country
# Australia         AUS
# Austria           AUT
# Belgium           BEL
# Canada            CAN
# Denmark           DNK
# Finland           FIN
# France            FRA
# Germany           DEU
# Hungary           HUN
# Italy             ITA
# Japan             JPN
# Korea             KOR
# United Kingdom    GBR
# United States     USA
# Brazil            BRA
# Israel            ISR

# %%
so_df.set_index('Country')
# Out:
#                     ResponseId  \
# Country
# Slovakia                     1
# Netherlands                  2
# Russian Federation           3
# Austria                      4
# United Kingdom               5
# ...                        ...
# United States            83435
# Benin                    83436
# United States            83437
# Canada                   83438
# Brazil                   83439
#
#                                                            MainBranch  \
# Country
# Slovakia                               I am a developer by profession
# Netherlands                    I am a student who is learning to code
# Russian Federation  I am not primarily a developer, but I write co...
# Austria                                I am a developer by profession
# United Kingdom                         I am a developer by profession
# ...                                                               ...
# United States                          I am a developer by profession
# Benin                                  I am a developer by profession
# United States                          I am a developer by profession
# Canada                                 I am a developer by profession
# Brazil                                 I am a developer by profession
#
#                                                            Employment  \
# Country
# Slovakia            Independent contractor, freelancer, or self-em...
# Netherlands                                        Student, full-time
# Russian Federation                                 Student, full-time
# Austria                                            Employed full-time
# United Kingdom      Independent contractor, freelancer, or self-em...
# ...                                                               ...
# United States                                      Employed full-time
# Benin               Independent contractor, freelancer, or self-em...
# United States                                      Employed full-time
# Canada                                             Employed full-time
# Brazil                                             Employed full-time
#
#                       US_State UK_Country  \
# Country
# Slovakia                   NaN        NaN
# Netherlands                NaN        NaN
# Russian Federation         NaN        NaN
# Austria                    NaN        NaN
# United Kingdom             NaN    England
# ...                        ...        ...
# United States            Texas        NaN
# Benin                      NaN        NaN
# United States       New Jersey        NaN
# Canada                     NaN        NaN
# Brazil                     NaN        NaN
#
#                                                               EdLevel  \
# Country
# Slovakia            Secondary school (e.g. American high school, G...
# Netherlands              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Russian Federation       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Austria               Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# United Kingdom        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                               ...
# United States            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Benin                    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# United States       Secondary school (e.g. American high school, G...
# Canada                   Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Brazil                             Professional degree (JD, MD, etc.)
#
#                        Age1stCode  \
# Country
# Slovakia            18 - 24 years
# Netherlands         11 - 17 years
# Russian Federation  11 - 17 years
# Austria             11 - 17 years
# United Kingdom       5 - 10 years
# ...                           ...
# United States       11 - 17 years
# Benin               11 - 17 years
# United States       11 - 17 years
# Canada              11 - 17 years
# Brazil              11 - 17 years
#
#                                                             LearnCode  \
# Country
# Slovakia            Coding Bootcamp;Other online resources (ex: vi...
# Netherlands         Other online resources (ex: videos, blogs, etc...
# Russian Federation  Other online resources (ex: videos, blogs, etc...
# Austria                                                           NaN
# United Kingdom                                Friend or family member
# ...                                                               ...
# United States       Other online resources (ex: videos, blogs, etc...
# Benin               Other online resources (ex: videos, blogs, etc...
# United States                                                  School
# Canada              Online Courses or Certification;Books / Physic...
# Brazil                                                         School
#
#                    YearsCode YearsCodePro  ...              Age Gender Trans  \
# Country                                    ...
# Slovakia                 NaN          NaN  ...  25-34 years old    Man    No
# Netherlands                7          NaN  ...  18-24 years old    Man    No
# Russian Federation       NaN          NaN  ...  18-24 years old    Man    No
# Austria                  NaN          NaN  ...  35-44 years old    Man    No
# United Kingdom            17           10  ...  25-34 years old    Man    No
# ...                      ...          ...  ...              ...    ...   ...
# United States              6            5  ...  25-34 years old    Man    No
# Benin                      4            2  ...  18-24 years old    Man    No
# United States             10            4  ...  25-34 years old    Man    No
# Canada                     5            3  ...  25-34 years old    Man    No
# Brazil                    14            4  ...  18-24 years old    Man    No
#
#                                   Sexuality                     Ethnicity  \
# Country
# Slovakia            Straight / Heterosexual  White or of European descent
# Netherlands         Straight / Heterosexual  White or of European descent
# Russian Federation        Prefer not to say             Prefer not to say
# Austria             Straight / Heterosexual  White or of European descent
# United Kingdom                          NaN  White or of European descent
# ...                                     ...                           ...
# United States       Straight / Heterosexual  White or of European descent
# Benin               Straight / Heterosexual   Black or of African descent
# United States                           NaN  White or of European descent
# Canada              Straight / Heterosexual  White or of European descent
# Brazil              Straight / Heterosexual        Hispanic or Latino/a/x
#
#                                   Accessibility  \
# Country
# Slovakia                      None of the above
# Netherlands                   None of the above
# Russian Federation            None of the above
# Austria             I am deaf / hard of hearing
# United Kingdom                None of the above
# ...                                         ...
# United States                 None of the above
# Benin                         None of the above
# United States                 None of the above
# Canada                        None of the above
# Brazil                        None of the above
#
#                                                          MentalHealth  \
# Country
# Slovakia                                            None of the above
# Netherlands                                         None of the above
# Russian Federation                                  None of the above
# Austria                                                           NaN
# United Kingdom                                                    NaN
# ...                                                               ...
# United States       I have a concentration and/or memory disorder ...
# Benin                                               None of the above
# United States                                       None of the above
# Canada              I have a mood or emotional disorder (e.g. depr...
# Brazil                                              None of the above
#
#                              SurveyLength                  SurveyEase  \
# Country
# Slovakia            Appropriate in length                        Easy
# Netherlands         Appropriate in length                        Easy
# Russian Federation  Appropriate in length                        Easy
# Austria             Appropriate in length  Neither easy nor difficult
# United Kingdom      Appropriate in length                        Easy
# ...                                   ...                         ...
# United States       Appropriate in length                        Easy
# Benin               Appropriate in length                        Easy
# United States       Appropriate in length  Neither easy nor difficult
# Canada              Appropriate in length  Neither easy nor difficult
# Brazil              Appropriate in length                        Easy
#
#                    ConvertedCompYearly
# Country
# Slovakia                     62,268.00
# Netherlands                        NaN
# Russian Federation                 NaN
# Austria                            NaN
# United Kingdom                     NaN
# ...                                ...
# United States               160,500.00
# Benin                         3,960.00
# United States                90,000.00
# Canada                      816,816.00
# Brazil                       21,168.00
#
# [83439 rows x 47 columns]

# %%
oecd_df.join(so_df.set_index('Country'))
# Out:
#           abbrev  ResponseId  \
# Country
# Australia    AUS         210
# Australia    AUS         743
# Australia    AUS         992
# Australia    AUS        1594
# Australia    AUS        1779
# ...          ...         ...
# Israel       ISR       82948
# Israel       ISR       83072
# Israel       ISR       83075
# Israel       ISR       83244
# Israel       ISR       83419
#
#                                                   MainBranch  \
# Country
# Australia  I am not primarily a developer, but I write co...
# Australia                     I am a developer by profession
# Australia                                      None of these
# Australia                     I am a developer by profession
# Australia                     I am a developer by profession
# ...                                                      ...
# Israel                        I am a developer by profession
# Israel                        I am a developer by profession
# Israel                        I am a developer by profession
# Israel                        I am a developer by profession
# Israel                I am a student who is learning to code
#
#                    Employment US_State UK_Country  \
# Country
# Australia  Employed full-time      NaN        NaN
# Australia  Employed part-time      NaN        NaN
# Australia  Student, full-time      NaN        NaN
# Australia  Employed full-time      NaN        NaN
# Australia  Employed full-time      NaN        NaN
# ...                       ...      ...        ...
# Israel     Employed full-time      NaN        NaN
# Israel     Employed part-time      NaN        NaN
# Israel     Employed full-time      NaN        NaN
# Israel     Employed full-time      NaN        NaN
# Israel     Student, full-time      NaN        NaN
#
#                                                      EdLevel     Age1stCode  \
# Country
# Australia    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# Australia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   5 - 10 years
# Australia  Secondary school (e.g. American high school, G...  11 - 17 years
# Australia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   5 - 10 years
# Australia  Some college/university study without earning ...  25 - 34 years
# ...                                                      ...            ...
# Israel          Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# Israel     Some college/university study without earning ...  11 - 17 years
# Israel                                        Something else  11 - 17 years
# Israel     Secondary school (e.g. American high school, G...  18 - 24 years
# Israel                             Primary/elementary school   5 - 10 years
#
#                                                    LearnCode YearsCode  ...  \
# Country                                                                 ...
# Australia                     School;Friend or family member         4  ...
# Australia  Other online resources (ex: videos, blogs, etc...        11  ...
# Australia  Coding Bootcamp;Other online resources (ex: vi...       NaN  ...
# Australia  Coding Bootcamp;Other online resources (ex: vi...        24  ...
# Australia                                    Coding Bootcamp         2  ...
# ...                                                      ...       ...  ...
# Israel     Coding Bootcamp;School;Online Courses or Certi...         7  ...
# Israel     Other online resources (ex: videos, blogs, etc...         5  ...
# Israel     Coding Bootcamp;Other online resources (ex: vi...         5  ...
# Israel                               Other (please specify):        36  ...
# Israel     Other online resources (ex: videos, blogs, etc...         5  ...
#
#                           Age  \
# Country
# Australia     35-44 years old
# Australia     18-24 years old
# Australia     18-24 years old
# Australia     25-34 years old
# Australia     25-34 years old
# ...                       ...
# Israel        18-24 years old
# Israel        25-34 years old
# Israel        18-24 years old
# Israel        45-54 years old
# Israel     Under 18 years old
#
#                                                       Gender Trans  \
# Country
# Australia                                                Man    No
# Australia                                                Man    No
# Australia                                                Man    No
# Australia                                                Man    No
# Australia                                                Man    No
# ...                                                      ...   ...
# Israel                                                   Man    No
# Israel                                                   Man    No
# Israel                                                   Man    No
# Israel                                                   Man    No
# Israel     Non-binary, genderqueer, or gender non-conforming    No
#
#                          Sexuality  \
# Country
# Australia  Straight / Heterosexual
# Australia                 Bisexual
# Australia  Straight / Heterosexual
# Australia  Straight / Heterosexual
# Australia  Straight / Heterosexual
# ...                            ...
# Israel     Straight / Heterosexual
# Israel     Straight / Heterosexual
# Israel     Straight / Heterosexual
# Israel     Straight / Heterosexual
# Israel              Gay or Lesbian
#
#                                                    Ethnicity  \
# Country
# Australia                       White or of European descent
# Australia                       White or of European descent
# Australia  White or of European descent;Southeast Asian;B...
# Australia                       White or of European descent
# Australia                       White or of European descent
# ...                                                      ...
# Israel           White or of European descent;Middle Eastern
# Israel           White or of European descent;Middle Eastern
# Israel                          White or of European descent
# Israel                          White or of European descent
# Israel           White or of European descent;Middle Eastern
#
#                Accessibility  \
# Country
# Australia  None of the above
# Australia  None of the above
# Australia  None of the above
# Australia  None of the above
# Australia  None of the above
# ...                      ...
# Israel     None of the above
# Israel     None of the above
# Israel     None of the above
# Israel     None of the above
# Israel     None of the above
#
#                                                 MentalHealth  \
# Country
# Australia                                  None of the above
# Australia                         I have an anxiety disorder
# Australia                                  Prefer not to say
# Australia                                  None of the above
# Australia                                  None of the above
# ...                                                      ...
# Israel                                     None of the above
# Israel     I have a concentration and/or memory disorder ...
# Israel     I have a concentration and/or memory disorder ...
# Israel                                     None of the above
# Israel                                     None of the above
#
#                     SurveyLength                  SurveyEase  \
# Country
# Australia  Appropriate in length                        Easy
# Australia              Too short                        Easy
# Australia  Appropriate in length                        Easy
# Australia  Appropriate in length                        Easy
# Australia               Too long  Neither easy nor difficult
# ...                          ...                         ...
# Israel     Appropriate in length                        Easy
# Israel     Appropriate in length                        Easy
# Israel     Appropriate in length                        Easy
# Israel     Appropriate in length                        Easy
# Israel     Appropriate in length                        Easy
#
#           ConvertedCompYearly
# Country
# Australia           96,874.00
# Australia           16,050.00
# Australia                 NaN
# Australia           40,086.00
# Australia           60,132.00
# ...                       ...
# Israel              84,048.00
# Israel              84,048.00
# Israel                    NaN
# Israel             119,076.00
# Israel                    NaN
#
# [41369 rows x 48 columns]

# %%
# Create this pivot table again, only including countries in our OECD subset.
(
    oecd_df
    .join(so_df.set_index('Country'))
    .pivot_table(index='Country',
                 columns='EdLevel', 
                 values='ConvertedCompYearly')
)
# Out:
# EdLevel         Associate degree (A.A., A.S., etc.)  \
# Country
# Australia                                117,049.64
# Austria                                   43,623.38
# Belgium                                   35,664.00
# Brazil                                    25,347.42
# Canada                                    87,930.35
# Denmark                                   80,217.33
# Finland                                  282,353.67
# France                                    54,394.89
# Germany                                   98,530.52
# Hungary                                   51,041.00
# Israel                                   146,420.90
# Italy                                     36,427.94
# Japan                                    143,196.83
# Korea                                     26,408.67
# United Kingdom                           139,154.85
# United States                            206,568.32
#
# EdLevel         Bachelor’s degree (B.A., B.S., B.Eng., etc.)  \
# Country
# Australia                                         180,794.16
# Austria                                            66,096.13
# Belgium                                            68,474.70
# Brazil                                             47,681.23
# Canada                                            140,668.24
# Denmark                                            80,430.94
# Finland                                            69,381.34
# France                                             65,062.38
# Germany                                           102,751.23
# Hungary                                            48,756.45
# Israel                                            124,973.40
# Italy                                              73,697.22
# Japan                                              85,821.47
# Korea                                             102,098.03
# United Kingdom                                    136,671.88
# United States                                     284,798.46
#
# EdLevel         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  \
# Country
# Australia                                            106,794.32
# Austria                                               77,645.66
# Belgium                                               88,580.41
# Brazil                                                42,056.01
# Canada                                               144,733.35
# Denmark                                              115,751.85
# Finland                                               74,360.98
# France                                                94,585.73
# Germany                                              110,611.98
# Hungary                                               46,771.71
# Israel                                               128,492.71
# Italy                                                 79,132.19
# Japan                                                130,143.19
# Korea                                                118,153.39
# United Kingdom                                       163,233.22
# United States                                        248,945.46
#
# EdLevel         Other doctoral degree (Ph.D., Ed.D., etc.)  \
# Country
# Australia                                       150,234.96
# Austria                                          74,783.17
# Belgium                                          80,832.44
# Brazil                                           43,123.21
# Canada                                          102,989.35
# Denmark                                         102,785.19
# Finland                                          61,508.25
# France                                          140,402.86
# Germany                                         108,718.46
# Hungary                                          52,833.60
# Israel                                          131,812.62
# Italy                                            93,490.78
# Japan                                           157,239.40
# Korea                                            41,919.00
# United Kingdom                                  123,226.40
# United States                                   208,656.94
#
# EdLevel         Primary/elementary school  Professional degree (JD, MD, etc.)  \
# Country
# Australia                      153,327.50                          108,725.00
# Austria                         86,877.00                           38,915.33
# Belgium                     11,342,349.25                           71,000.20
# Brazil                           7,880.00                           25,449.67
# Canada                          73,787.83                           82,953.40
# Denmark                         91,056.57                          114,144.89
# Finland                         77,832.00                           83,016.00
# France                          34,181.00                           78,342.27
# Germany                         74,943.67                           97,330.14
# Hungary                         48,100.00                            9,852.00
# Israel                         100,514.57                          132,336.00
# Italy                          525,992.17                          117,121.37
# Japan                           44,965.00                                 NaN
# Korea                           28,164.00                           21,132.00
# United Kingdom                 413,035.40                          137,874.35
# United States                  186,642.00                          504,847.43
#
# EdLevel         Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)  \
# Country
# Australia                                              158,931.28
# Austria                                                 47,438.83
# Belgium                                                 43,224.13
# Brazil                                                  15,072.89
# Canada                                                 180,584.81
# Denmark                                                 90,411.74
# Finland                                                 59,424.32
# France                                                  53,981.81
# Germany                                                 82,865.84
# Hungary                                                 33,440.80
# Israel                                                  97,938.78
# Italy                                                   75,114.40
# Japan                                                   57,916.40
# Korea                                                   50,874.73
# United Kingdom                                         135,994.32
# United States                                          169,139.79
#
# EdLevel         Some college/university study without earning a degree  \
# Country
# Australia                                              127,063.53
# Austria                                                 53,906.05
# Belgium                                                 88,006.29
# Brazil                                                  39,978.02
# Canada                                                 155,090.08
# Denmark                                                 85,131.35
# Finland                                                 89,255.56
# France                                                  55,119.45
# Germany                                                 95,737.77
# Hungary                                                 37,102.89
# Israel                                                 130,049.04
# Italy                                                   81,531.72
# Japan                                                   91,163.04
# Korea                                                   80,391.00
# United Kingdom                                         128,298.28
# United States                                          231,506.51
#
# EdLevel         Something else
# Country
# Australia           231,987.17
# Austria              45,772.53
# Belgium              27,035.50
# Brazil               20,288.71
# Canada               60,795.17
# Denmark              95,479.86
# Finland              35,024.00
# France               42,884.04
# Germany             109,333.99
# Hungary              28,911.00
# Israel               96,142.50
# Italy                32,690.22
# Japan               194,514.00
# Korea               125,556.00
# United Kingdom      103,344.70
# United States       115,890.29

# %%
oecd_df.join(so_df.set_index('Country'))
# Out:
#           abbrev  ResponseId  \
# Country
# Australia    AUS         210
# Australia    AUS         743
# Australia    AUS         992
# Australia    AUS        1594
# Australia    AUS        1779
# ...          ...         ...
# Israel       ISR       82948
# Israel       ISR       83072
# Israel       ISR       83075
# Israel       ISR       83244
# Israel       ISR       83419
#
#                                                   MainBranch  \
# Country
# Australia  I am not primarily a developer, but I write co...
# Australia                     I am a developer by profession
# Australia                                      None of these
# Australia                     I am a developer by profession
# Australia                     I am a developer by profession
# ...                                                      ...
# Israel                        I am a developer by profession
# Israel                        I am a developer by profession
# Israel                        I am a developer by profession
# Israel                        I am a developer by profession
# Israel                I am a student who is learning to code
#
#                    Employment US_State UK_Country  \
# Country
# Australia  Employed full-time      NaN        NaN
# Australia  Employed part-time      NaN        NaN
# Australia  Student, full-time      NaN        NaN
# Australia  Employed full-time      NaN        NaN
# Australia  Employed full-time      NaN        NaN
# ...                       ...      ...        ...
# Israel     Employed full-time      NaN        NaN
# Israel     Employed part-time      NaN        NaN
# Israel     Employed full-time      NaN        NaN
# Israel     Employed full-time      NaN        NaN
# Israel     Student, full-time      NaN        NaN
#
#                                                      EdLevel     Age1stCode  \
# Country
# Australia    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# Australia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   5 - 10 years
# Australia  Secondary school (e.g. American high school, G...  11 - 17 years
# Australia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   5 - 10 years
# Australia  Some college/university study without earning ...  25 - 34 years
# ...                                                      ...            ...
# Israel          Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# Israel     Some college/university study without earning ...  11 - 17 years
# Israel                                        Something else  11 - 17 years
# Israel     Secondary school (e.g. American high school, G...  18 - 24 years
# Israel                             Primary/elementary school   5 - 10 years
#
#                                                    LearnCode YearsCode  ...  \
# Country                                                                 ...
# Australia                     School;Friend or family member         4  ...
# Australia  Other online resources (ex: videos, blogs, etc...        11  ...
# Australia  Coding Bootcamp;Other online resources (ex: vi...       NaN  ...
# Australia  Coding Bootcamp;Other online resources (ex: vi...        24  ...
# Australia                                    Coding Bootcamp         2  ...
# ...                                                      ...       ...  ...
# Israel     Coding Bootcamp;School;Online Courses or Certi...         7  ...
# Israel     Other online resources (ex: videos, blogs, etc...         5  ...
# Israel     Coding Bootcamp;Other online resources (ex: vi...         5  ...
# Israel                               Other (please specify):        36  ...
# Israel     Other online resources (ex: videos, blogs, etc...         5  ...
#
#                           Age  \
# Country
# Australia     35-44 years old
# Australia     18-24 years old
# Australia     18-24 years old
# Australia     25-34 years old
# Australia     25-34 years old
# ...                       ...
# Israel        18-24 years old
# Israel        25-34 years old
# Israel        18-24 years old
# Israel        45-54 years old
# Israel     Under 18 years old
#
#                                                       Gender Trans  \
# Country
# Australia                                                Man    No
# Australia                                                Man    No
# Australia                                                Man    No
# Australia                                                Man    No
# Australia                                                Man    No
# ...                                                      ...   ...
# Israel                                                   Man    No
# Israel                                                   Man    No
# Israel                                                   Man    No
# Israel                                                   Man    No
# Israel     Non-binary, genderqueer, or gender non-conforming    No
#
#                          Sexuality  \
# Country
# Australia  Straight / Heterosexual
# Australia                 Bisexual
# Australia  Straight / Heterosexual
# Australia  Straight / Heterosexual
# Australia  Straight / Heterosexual
# ...                            ...
# Israel     Straight / Heterosexual
# Israel     Straight / Heterosexual
# Israel     Straight / Heterosexual
# Israel     Straight / Heterosexual
# Israel              Gay or Lesbian
#
#                                                    Ethnicity  \
# Country
# Australia                       White or of European descent
# Australia                       White or of European descent
# Australia  White or of European descent;Southeast Asian;B...
# Australia                       White or of European descent
# Australia                       White or of European descent
# ...                                                      ...
# Israel           White or of European descent;Middle Eastern
# Israel           White or of European descent;Middle Eastern
# Israel                          White or of European descent
# Israel                          White or of European descent
# Israel           White or of European descent;Middle Eastern
#
#                Accessibility  \
# Country
# Australia  None of the above
# Australia  None of the above
# Australia  None of the above
# Australia  None of the above
# Australia  None of the above
# ...                      ...
# Israel     None of the above
# Israel     None of the above
# Israel     None of the above
# Israel     None of the above
# Israel     None of the above
#
#                                                 MentalHealth  \
# Country
# Australia                                  None of the above
# Australia                         I have an anxiety disorder
# Australia                                  Prefer not to say
# Australia                                  None of the above
# Australia                                  None of the above
# ...                                                      ...
# Israel                                     None of the above
# Israel     I have a concentration and/or memory disorder ...
# Israel     I have a concentration and/or memory disorder ...
# Israel                                     None of the above
# Israel                                     None of the above
#
#                     SurveyLength                  SurveyEase  \
# Country
# Australia  Appropriate in length                        Easy
# Australia              Too short                        Easy
# Australia  Appropriate in length                        Easy
# Australia  Appropriate in length                        Easy
# Australia               Too long  Neither easy nor difficult
# ...                          ...                         ...
# Israel     Appropriate in length                        Easy
# Israel     Appropriate in length                        Easy
# Israel     Appropriate in length                        Easy
# Israel     Appropriate in length                        Easy
# Israel     Appropriate in length                        Easy
#
#           ConvertedCompYearly
# Country
# Australia           96,874.00
# Australia           16,050.00
# Australia                 NaN
# Australia           40,086.00
# Australia           60,132.00
# ...                       ...
# Israel              84,048.00
# Israel              84,048.00
# Israel                    NaN
# Israel             119,076.00
# Israel                    NaN
#
# [41369 rows x 48 columns]

# %%
# In which of these countries does someone with an associate degree earn the most? 
(
    oecd_df.join(so_df.set_index('Country'))
    .pivot_table(index='Country',
                 columns='EdLevel', 
                 values='ConvertedCompYearly')['Associate degree (A.A., A.S., etc.)']
    .sort_values(ascending=False)
)
# Out:
# Country
# Finland          282,353.67
# United States    206,568.32
# Israel           146,420.90
# Japan            143,196.83
# United Kingdom   139,154.85
# Australia        117,049.64
# Germany           98,530.52
# Canada            87,930.35
# Denmark           80,217.33
# France            54,394.89
# Hungary           51,041.00
# Austria           43,623.38
# Italy             36,427.94
# Belgium           35,664.00
# Korea             26,408.67
# Brazil            25,347.42
# Name: Associate degree (A.A., A.S., etc.), dtype: float64

# %%
# In which of them does someone with a doctoral degree earn the most?
# In which of these countries does someone with an associate degree earn the most? 
(
    oecd_df
    .join(so_df.set_index('Country'))
    .pivot_table(index='Country',
                 columns='EdLevel', 
                 values='ConvertedCompYearly')['Other doctoral degree (Ph.D., Ed.D., etc.)']
    .sort_values(ascending=False)
)
# Out:
# Country
# United States    208,656.94
# Japan            157,239.40
# Australia        150,234.96
# France           140,402.86
# Israel           131,812.62
# United Kingdom   123,226.40
# Germany          108,718.46
# Canada           102,989.35
# Denmark          102,785.19
# Italy             93,490.78
# Belgium           80,832.44
# Austria           74,783.17
# Finland           61,508.25
# Hungary           52,833.60
# Brazil            43,123.21
# Korea             41,919.00
# Name: Other doctoral degree (Ph.D., Ed.D., etc.), dtype: float64

# %%
# Remove rows from `so_df` in which `LanguageHaveWorkedWith` is `NaN`.
so_df = so_df.dropna(subset=['LanguageHaveWorkedWith'])

# %%
# Remove rows from `so_df` in which Python isn't included 
# as a commonly used language (`LanguageHaveWorkedWith`).
so_df = (
    so_df.loc[so_df['LanguageHaveWorkedWith'].str.contains('Python')]
)

# %%
# Remove rows from `so_df` in which `YearsCode` is `NaN`.
so_df = (so_df
         .dropna(subset=['YearsCode'])
        )

# %%
so_df.loc[so_df['YearsCode'] == 'Less than 1 year', 'YearsCode'] = 0
so_df.loc[so_df['YearsCode'] == 'More than 50 years', 'YearsCode'] = 51

# %%
so_df['YearsCode'] = so_df['YearsCode'].astype(int)

# %%
# Create a new column in `so_df`, called `experience`, which will categorize the values in `YearsCode`

so_df['experience'] = pd.cut(so_df['YearsCode'], 
                             bins=[-1, 0, 2, 5, 10, 100], 
                             labels=['Less than 1 year', '1-2 years', '3-5 years', '6-10 years', '11+ years'])

# %%
# According to the Python survey, what proportion of Python developers have each level of experience?
so_df['experience'].value_counts(normalize=True)
# Out:
# experience
# 11+ years          0.37
# 6-10 years         0.32
# 3-5 years          0.22
# 1-2 years          0.07
# Less than 1 year   0.02
# Name: proportion, dtype: float64

# %%
py_df['other.lang']
# Out:
#        Bash / Shell   C#  C/C++ Clojure CoffeeScript   Go Groovy  HTML/CSS  \
# 0      Bash / Shell  NaN    NaN     NaN          NaN  NaN    NaN       NaN
# 1               NaN   C#    NaN     NaN          NaN  NaN    NaN       NaN
# 2      Bash / Shell  NaN  C/C++     NaN          NaN  NaN    NaN       NaN
# 3      Bash / Shell  NaN    NaN     NaN          NaN  NaN    NaN  HTML/CSS
# 4      Bash / Shell  NaN  C/C++     NaN          NaN  NaN    NaN  HTML/CSS
# ...             ...  ...    ...     ...          ...  ...    ...       ...
# 54457  Bash / Shell  NaN  C/C++     NaN          NaN  NaN    NaN       NaN
# 54458  Bash / Shell  NaN    NaN     NaN          NaN  NaN    NaN  HTML/CSS
# 54459  Bash / Shell  NaN    NaN     NaN          NaN   Go    NaN  HTML/CSS
# 54460  Bash / Shell  NaN  C/C++     NaN          NaN  NaN    NaN  HTML/CSS
# 54461           NaN  NaN    NaN     NaN          NaN  NaN    NaN  HTML/CSS
#
#        Java  JavaScript  ...  PHP  Perl    R Ruby Rust  SQL Scala Swift  \
# 0       NaN         NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN
# 1      Java  JavaScript  ...  NaN   NaN    R  NaN  NaN  SQL   NaN   NaN
# 2       NaN         NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN
# 3       NaN  JavaScript  ...  NaN   NaN  NaN  NaN  NaN  SQL   NaN   NaN
# 4      Java  JavaScript  ...  NaN   NaN  NaN  NaN  NaN  SQL   NaN   NaN
# ...     ...         ...  ...  ...   ...  ...  ...  ...  ...   ...   ...
# 54457   NaN         NaN  ...  NaN   NaN    R  NaN  NaN  NaN   NaN   NaN
# 54458   NaN  JavaScript  ...  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN
# 54459   NaN  JavaScript  ...  PHP   NaN  NaN  NaN  NaN  SQL   NaN   NaN
# 54460   NaN  JavaScript  ...  PHP   NaN  NaN  NaN  NaN  SQL   NaN   NaN
# 54461   NaN  JavaScript  ...  NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN
#
#        TypeScript Visual Basic
# 0             NaN          NaN
# 1      TypeScript          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 54457         NaN          NaN
# 54458         NaN          NaN
# 54459  TypeScript          NaN
# 54460         NaN          NaN
# 54461         NaN          NaN
#
# [54462 rows x 24 columns]
