# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# Open the file `alice-in-wonderland.txt`, and read it into a `pandas` series
# or data frame, such that each word is a separate value.
filename = '../data/alice-in-wonderland.txt'

s = Series(open(filename, encoding='utf-8').read().split())
s.head()
# Out:
# 0         ﻿The
# 1      Project
# 2    Gutenberg
# 3        EBook
# 4           of
# dtype: object

# %%
# What are the 10 most common words in the book?
s.value_counts().head(10)
# Out:
# the     732
# and     362
# a       321
# to      311
# of      300
# in      211
# she     197
# was     160
# said    129
# it      122
# Name: count, dtype: int64

# %%
# Does this change if we count the words without regard to case?
(
    s
    .str
    .lower()
    .value_counts()
    .head(10)
)
# Out:
# the    792
# and    379
# a      325
# to     318
# of     313
# she    232
# in     222
# was    160
# you    141
# it     136
# Name: count, dtype: int64

# %%
# Does it change if we remove punctuation marks and quote marks
# from the beginning and end of each word?
import string

(
    s
    .str
    .strip(string.punctuation)
    .value_counts()
    .head(10)
)
# Out:
# the      735
# and      384
# a        322
# to       320
# of       303
# in       214
# she      201
# was      167
# Alice    166
# it       164
# Name: count, dtype: int64

# %%
# How many capitalized words does the book contain?

(
    s
    .loc[s.str.contains(r'^[A-Z]\w*$', 
                        regex=True)]
    .count()
)
# Out:
# np.int64(1100)

# %%
# If we ignore punctuation and quotes before the start of a word, 
# how many capitalized words does the book contain?

(
    s
    .loc[s.str.strip(string.punctuation)
    .str
    .contains('^[A-Z]\w*$', regex=True)]
    .count()
)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_21397/4138551257.py:8: SyntaxWarning: invalid escape sequence '\w'
#   .contains('^[A-Z]\w*$', regex=True)]
# np.int64(1686)
